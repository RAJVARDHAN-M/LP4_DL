# %%
# Specify the path to your text file
file_path = '/content/CBOW.txt'

# Open the file in read mode
with open(file_path, 'r') as file:
    # Read the entire contents of the file
    file_contents = file.read()

# %%
file_contents
# Out:
# 'The speed of transmission is an important point of difference between the two viruses. Influenza has a shorter median incubation period (the time from infection to appearance of symptoms) and a shorter serial interval (the time between successive cases) than COVID-19 virus. The serial interval for COVID-19 virus is estimated to be 5-6 days, while for influenza virus, the serial interval is 3 days. This means that influenza can spread faster than COVID-19. \n\nFurther, transmission in the first 3-5 days of illness, or potentially pre-symptomatic transmission –transmission of the virus before the appearance of symptoms – is a major driver of transmission for influenza. In contrast, while we are learning that there are people who can shed COVID-19 virus 24-48 hours prior to symptom onset, at present, this does not appear to be a major driver of transmission. \n\nThe reproductive number – the number of secondary infections generated from one infected individual – is understood to be between 2 and 2.5 for COVID-19 virus, higher than for influenza. However, estimates for both COVID-19 and influenza viruses are very context and time-specific, making direct comparisons more difficult.  '

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample sentences
sentences = file_contents.split('.')

# Tokenize the sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# Generate context-target pairs for training
window_size = 3
# tokenizer.fit_on_texts(sentences)
tokenized_sentences = tokenizer.texts_to_sequences(sentences)

data, labels = [], []
for sentence in tokenized_sentences:
    for i, target_word in enumerate(sentence):
        context = [
            sentence[j] for j in range(i - window_size, i + window_size + 1)
            if j != i and 0 <= j < len(sentence)
        ]
        data.append(context)
        labels.append(target_word)

# Convert data and labels to numpy arrays
data = pad_sequences(data)
labels = np.array(labels)

# Define CBOW model
embedding_dim = 50

model = models.Sequential([
    layers.Embedding(input_dim=total_words, output_dim=embedding_dim, input_length=window_size * 2),
    layers.GlobalAveragePooling1D(),
    layers.Dense(total_words, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(data, labels, epochs=200, verbose=1)

# Get the word embeddings
word_embeddings = model.get_layer(index=0).get_weights()[0]

# Save or use the word embeddings as needed
# Out:
# Epoch 1/200
# 7/7 [==============================] - 1s 4ms/step - loss: 4.6349 - accuracy: 0.0152
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.6258 - accuracy: 0.1061
# Epoch 3/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.6182 - accuracy: 0.1667
# Epoch 4/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.6106 - accuracy: 0.1869
# Epoch 5/200
# 7/7 [==============================] - 0s 7ms/step - loss: 4.6031 - accuracy: 0.2172
# Epoch 6/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.5955 - accuracy: 0.2172
# Epoch 7/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.5874 - accuracy: 0.2222
# Epoch 8/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.5788 - accuracy: 0.2323
# Epoch 9/200
# 7/7 [==============================] - 0s 7ms/step - loss: 4.5696 - accuracy: 0.2475
# Epoch 10/200
# 7/7 [==============================] - 0s 7ms/step - loss: 4.5598 - accuracy: 0.2475
# Epoch 11/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.5491 - accuracy: 0.2374
# Epoch 12/200
# 7/7 [==============================] - 0s 7ms/step - loss: 4.5374 - accuracy: 0.2273
# Epoch 13/200
# 7/7 [==============================] - 0s 8ms/step - loss: 4.5246 - accuracy: 0.2172
# Epoch 14/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.5105 - accuracy: 0.2222
# Epoch 15/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.4956 - accuracy: 0.2273
# Epoch 16/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.4796 - accuracy: 0.2071
# Epoch 17/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.4617 - accuracy: 0.2121
# Epoch 18/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.4427 - accuracy: 0.2121
# Epoch 19/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.4231 - accuracy: 0.2121
# Epoch 20/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.4019 - accuracy: 0.2121
# Epoch 21/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.3791 - accuracy: 0.2071
# Epoch 22/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.3563 - accuracy: 0.2020
# Epoch 23/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.3312 - accuracy: 0.2071
# Epoch 24/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.3053 - accuracy: 0.2121
# Epoch 25/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.2779 - accuracy: 0.2071
# Epoch 26/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.2498 - accuracy: 0.2071
# Epoch 27/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.2200 - accuracy: 0.2071
# Epoch 28/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.1905 - accuracy: 0.2020
# Epoch 29/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.1591 - accuracy: 0.2071
# Epoch 30/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.1279 - accuracy: 0.2071
# Epoch 31/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.0962 - accuracy: 0.2071
# Epoch 32/200
# 7/7 [==============================] - 0s 6ms/step - loss: 4.0642 - accuracy: 0.2071
# Epoch 33/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.0330 - accuracy: 0.2121
# Epoch 34/200
# 7/7 [==============================] - 0s 5ms/step - loss: 4.0010 - accuracy: 0.2121
# Epoch 35/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.9683 - accuracy: 0.2222
# Epoch 36/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.9362 - accuracy: 0.2172
# Epoch 37/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.9043 - accuracy: 0.2071
# Epoch 38/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.8719 - accuracy: 0.2020
# Epoch 39/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.8395 - accuracy: 0.2020
# Epoch 40/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.8076 - accuracy: 0.2020
# Epoch 41/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.7765 - accuracy: 0.2172
# Epoch 42/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.7452 - accuracy: 0.2172
# Epoch 43/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.7149 - accuracy: 0.2172
# Epoch 44/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.6839 - accuracy: 0.2222
# Epoch 45/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.6536 - accuracy: 0.2273
# Epoch 46/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.6239 - accuracy: 0.2323
# Epoch 47/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.5942 - accuracy: 0.2323
# Epoch 48/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.5648 - accuracy: 0.2323
# Epoch 49/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.5361 - accuracy: 0.2424
# Epoch 50/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.5078 - accuracy: 0.2273
# Epoch 51/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.4799 - accuracy: 0.2323
# Epoch 52/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.4518 - accuracy: 0.2374
# Epoch 53/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.4245 - accuracy: 0.2424
# Epoch 54/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.3971 - accuracy: 0.2424
# Epoch 55/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.3695 - accuracy: 0.2323
# Epoch 56/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.3432 - accuracy: 0.2323
# Epoch 57/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.3160 - accuracy: 0.2323
# Epoch 58/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.2900 - accuracy: 0.2273
# Epoch 59/200
# 7/7 [==============================] - 0s 4ms/step - loss: 3.2640 - accuracy: 0.2323
# Epoch 60/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.2381 - accuracy: 0.2323
# Epoch 61/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.2126 - accuracy: 0.2323
# Epoch 62/200
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1872 - accuracy: 0.2374
# Epoch 63/200
# 7/7 [==============================] - 0s 8ms/step - loss: 3.1621 - accuracy: 0.2475
# Epoch 64/200
# 7/7 [==============================] - 0s 7ms/step - loss: 3.1370 - accuracy: 0.2525
# Epoch 65/200
# 7/7 [==============================] - 0s 7ms/step - loss: 3.1123 - accuracy: 0.2576
# Epoch 66/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0885 - accuracy: 0.2626
# Epoch 67/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0635 - accuracy: 0.2626
# Epoch 68/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.0396 - accuracy: 0.2677
# Epoch 69/200
# 7/7 [==============================] - 0s 5ms/step - loss: 3.0152 - accuracy: 0.2677
# Epoch 70/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.9912 - accuracy: 0.2677
# Epoch 71/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.9676 - accuracy: 0.2677
# Epoch 72/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.9444 - accuracy: 0.2727
# Epoch 73/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9213 - accuracy: 0.2778
# Epoch 74/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.8989 - accuracy: 0.2929
# Epoch 75/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.8762 - accuracy: 0.2929
# Epoch 76/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.8532 - accuracy: 0.2980
# Epoch 77/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.8310 - accuracy: 0.3030
# Epoch 78/200
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8079 - accuracy: 0.3131
# Epoch 79/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.7856 - accuracy: 0.3030
# Epoch 80/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.7633 - accuracy: 0.3182
# Epoch 81/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.7415 - accuracy: 0.3384
# Epoch 82/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.7192 - accuracy: 0.3434
# Epoch 83/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.6977 - accuracy: 0.3434
# Epoch 84/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.6760 - accuracy: 0.3636
# Epoch 85/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.6550 - accuracy: 0.3737
# Epoch 86/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.6347 - accuracy: 0.3838
# Epoch 87/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.6143 - accuracy: 0.3838
# Epoch 88/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.5933 - accuracy: 0.3889
# Epoch 89/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.5727 - accuracy: 0.3939
# Epoch 90/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.5529 - accuracy: 0.3939
# Epoch 91/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.5325 - accuracy: 0.4040
# Epoch 92/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.5126 - accuracy: 0.4040
# Epoch 93/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.4932 - accuracy: 0.4040
# Epoch 94/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.4743 - accuracy: 0.4040
# Epoch 95/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.4550 - accuracy: 0.4141
# Epoch 96/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.4355 - accuracy: 0.4141
# Epoch 97/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.4181 - accuracy: 0.4242
# Epoch 98/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3988 - accuracy: 0.4293
# Epoch 99/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.3799 - accuracy: 0.4343
# Epoch 100/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3619 - accuracy: 0.4293
# Epoch 101/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3440 - accuracy: 0.4444
# Epoch 102/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3264 - accuracy: 0.4545
# Epoch 103/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3084 - accuracy: 0.4495
# Epoch 104/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2906 - accuracy: 0.4596
# Epoch 105/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2732 - accuracy: 0.4646
# Epoch 106/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2569 - accuracy: 0.4899
# Epoch 107/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2393 - accuracy: 0.4899
# Epoch 108/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2222 - accuracy: 0.5000
# Epoch 109/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2060 - accuracy: 0.5000
# Epoch 110/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1896 - accuracy: 0.5152
# Epoch 111/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1730 - accuracy: 0.5101
# Epoch 112/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1564 - accuracy: 0.5202
# Epoch 113/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1401 - accuracy: 0.5152
# Epoch 114/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1243 - accuracy: 0.5202
# Epoch 115/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1081 - accuracy: 0.5303
# Epoch 116/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0919 - accuracy: 0.5404
# Epoch 117/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0771 - accuracy: 0.5404
# Epoch 118/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0616 - accuracy: 0.5455
# Epoch 119/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0461 - accuracy: 0.5505
# Epoch 120/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0312 - accuracy: 0.5606
# Epoch 121/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0167 - accuracy: 0.5657
# Epoch 122/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0012 - accuracy: 0.5758
# Epoch 123/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9864 - accuracy: 0.5859
# Epoch 124/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9716 - accuracy: 0.5909
# Epoch 125/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9571 - accuracy: 0.5960
# Epoch 126/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9424 - accuracy: 0.6010
# Epoch 127/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9275 - accuracy: 0.5960
# Epoch 128/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9131 - accuracy: 0.6010
# Epoch 129/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8991 - accuracy: 0.6061
# Epoch 130/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8845 - accuracy: 0.6212
# Epoch 131/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8707 - accuracy: 0.6465
# Epoch 132/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8560 - accuracy: 0.6616
# Epoch 133/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8426 - accuracy: 0.6667
# Epoch 134/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8285 - accuracy: 0.6717
# Epoch 135/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8149 - accuracy: 0.6717
# Epoch 136/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8013 - accuracy: 0.6768
# Epoch 137/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7875 - accuracy: 0.6768
# Epoch 138/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7743 - accuracy: 0.6768
# Epoch 139/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7609 - accuracy: 0.6818
# Epoch 140/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7476 - accuracy: 0.6869
# Epoch 141/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7335 - accuracy: 0.6970
# Epoch 142/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7208 - accuracy: 0.6970
# Epoch 143/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7077 - accuracy: 0.7121
# Epoch 144/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6950 - accuracy: 0.7172
# Epoch 145/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6822 - accuracy: 0.7172
# Epoch 146/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6697 - accuracy: 0.7323
# Epoch 147/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6559 - accuracy: 0.7374
# Epoch 148/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6433 - accuracy: 0.7475
# Epoch 149/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6310 - accuracy: 0.7475
# Epoch 150/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6183 - accuracy: 0.7525
# Epoch 151/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6060 - accuracy: 0.7576
# Epoch 152/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5938 - accuracy: 0.7576
# Epoch 153/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5810 - accuracy: 0.7626
# Epoch 154/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5688 - accuracy: 0.7626
# Epoch 155/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5565 - accuracy: 0.7727
# Epoch 156/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5445 - accuracy: 0.7778
# Epoch 157/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5327 - accuracy: 0.7778
# Epoch 158/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5209 - accuracy: 0.7879
# Epoch 159/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5090 - accuracy: 0.7929
# Epoch 160/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4971 - accuracy: 0.7980
# Epoch 161/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4855 - accuracy: 0.8030
# Epoch 162/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4740 - accuracy: 0.8030
# Epoch 163/200
# 7/7 [==============================] - 0s 8ms/step - loss: 1.4627 - accuracy: 0.8030
# Epoch 164/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4513 - accuracy: 0.8131
# Epoch 165/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4402 - accuracy: 0.8131
# Epoch 166/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4284 - accuracy: 0.8131
# Epoch 167/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4173 - accuracy: 0.8232
# Epoch 168/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4062 - accuracy: 0.8283
# Epoch 169/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3957 - accuracy: 0.8333
# Epoch 170/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.3840 - accuracy: 0.8333
# Epoch 171/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.3735 - accuracy: 0.8333
# Epoch 172/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.3624 - accuracy: 0.8283
# Epoch 173/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.3516 - accuracy: 0.8333
# Epoch 174/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3409 - accuracy: 0.8333
# Epoch 175/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3298 - accuracy: 0.8384
# Epoch 176/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.3197 - accuracy: 0.8434
# Epoch 177/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3091 - accuracy: 0.8434
# Epoch 178/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2986 - accuracy: 0.8485
# Epoch 179/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2883 - accuracy: 0.8535
# Epoch 180/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2780 - accuracy: 0.8485
# Epoch 181/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2680 - accuracy: 0.8535
# Epoch 182/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.2570 - accuracy: 0.8586
# Epoch 183/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2472 - accuracy: 0.8586
# Epoch 184/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.2368 - accuracy: 0.8687
# Epoch 185/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2269 - accuracy: 0.8687
# Epoch 186/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2170 - accuracy: 0.8687
# Epoch 187/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2073 - accuracy: 0.8687
# Epoch 188/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1975 - accuracy: 0.8687
# Epoch 189/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1876 - accuracy: 0.8687
# Epoch 190/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1779 - accuracy: 0.8687
# Epoch 191/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1687 - accuracy: 0.8687
# Epoch 192/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1590 - accuracy: 0.8788
# Epoch 193/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1494 - accuracy: 0.8788
# Epoch 194/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1398 - accuracy: 0.8788
# Epoch 195/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1306 - accuracy: 0.8788
# Epoch 196/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1211 - accuracy: 0.8788
# Epoch 197/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1116 - accuracy: 0.8788
# Epoch 198/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1025 - accuracy: 0.8939
# Epoch 199/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0931 - accuracy: 0.8889
# Epoch 200/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0839 - accuracy: 0.8889

# %%
def cos(a,b):
  return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))

# %%
words = list(tokenizer.word_index.keys())

# %%
from sklearn.metrics.pairwise import cosine_similarity


target_word = 'influenza'


target_word_index = tokenizer.word_index[target_word]


target_embedding = word_embeddings[target_word_index]


similarities = cosine_similarity(target_embedding.reshape(1, -1), word_embeddings)[0]


most_similar_indices = similarities.argsort()[-5:][::-1]  # Adjust the number of similar words as needed


most_similar_words = [word for word, idx in tokenizer.word_index.items() if idx in most_similar_indices]

print(f"Most similar words to '{target_word}': {most_similar_words}")
# Out:
# Most similar words to 'influenza': ['influenza', 'means', 'spread', 'learning', 'people']
